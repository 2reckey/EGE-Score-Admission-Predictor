# %%
import pandas as pd
import numpy as np

# %%
parts = []
for i in range(10):
    part = pd.read_csv(f'Data/full_data_{i}.csv')
    parts.append(part)

df = pd.concat(parts, ignore_index=True)
df
# Out:
# C:\Users\2reckey\AppData\Local\Temp\ipykernel_8828\1509595890.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   part = pd.read_csv(f'Data/full_data_{i}.csv')
#          Year        University                         Faculty  \
# 0        2017               ВШЭ  Департамент иностранных языков
# 1        2017               ВШЭ  Департамент иностранных языков
# 2        2017               ВШЭ  Департамент иностранных языков
# 3        2017               ВШЭ  Департамент иностранных языков
# 4        2017               ВШЭ  Департамент иностранных языков
# ...       ...               ...                             ...
# 1641405  2022  МГТУ им. Баумана                      AllFaculty
# 1641406  2022  МГТУ им. Баумана                      AllFaculty
# 1641407  2022  МГТУ им. Баумана                      AllFaculty
# 1641408  2022  МГТУ им. Баумана                      AllFaculty
# 1641409  2022  МГТУ им. Баумана                      AllFaculty
#
#                                                    Program  \
# 0        Лингвистика (45.03.02) (Иностранные языки и ме...
# 1        Лингвистика (45.03.02) (Иностранные языки и ме...
# 2        Лингвистика (45.03.02) (Иностранные языки и ме...
# 3        Лингвистика (45.03.02) (Иностранные языки и ме...
# 4        Лингвистика (45.03.02) (Иностранные языки и ме...
# ...                                                    ...
# 1641405            Ядерные реакторы и материалы (14.05.01)
# 1641406            Ядерные реакторы и материалы (14.05.01)
# 1641407            Ядерные реакторы и материалы (14.05.01)
# 1641408            Ядерные реакторы и материалы (14.05.01)
# 1641409            Ядерные реакторы и материалы (14.05.01)
#
#                                 Name  Score   Avg_score  Num_subjects  Quota  \
# 0             Бунтман Вера Сергеевна    309  103.000000             3     30
# 1           Мунтян Марина Евгеньевна    308  102.666667             3     30
# 2        Соколова Виктория Сергеевна    307  102.333333             3     30
# 3             Ужакина Анна Андреевна    307  102.333333             3     30
# 4           Крюкова Алеся Алексеевна    306  102.000000             3     30
# ...                              ...    ...         ...           ...    ...
# 1641405                  16103802721    174   58.000000             3     48
# 1641406                  16530926467    170   56.666667             3     48
# 1641407                  18467618619    162   54.000000             3     48
# 1641408                  18625786822    160   53.333333             3     48
# 1641409                  18566551716    155   51.666667             3     48
#
#          All_app  ...  q25_by_2Q  q25_by_3Q  q25_by_4Q  q25_by_5Q  q25_by_6Q  \
# 0           1413  ...  99.333333  98.666667  98.000000  97.333333       97.0
# 1           1413  ...  99.333333  98.666667  98.000000  97.333333       97.0
# 2           1413  ...  99.333333  98.666667  98.000000  97.333333       97.0
# 3           1413  ...  99.333333  98.666667  98.000000  97.333333       97.0
# 4           1413  ...  99.333333  98.666667  98.000000  97.333333       97.0
# ...          ...  ...        ...        ...        ...        ...        ...
# 1641405      479  ...  91.000000  88.666667  86.666667  84.916667       83.0
# 1641406      479  ...  91.000000  88.666667  86.666667  84.916667       83.0
# 1641407      479  ...  91.000000  88.666667  86.666667  84.916667       83.0
# 1641408      479  ...  91.000000  88.666667  86.666667  84.916667       83.0
# 1641409      479  ...  91.000000  88.666667  86.666667  84.916667       83.0
#
#          q25_by_7Q  q25_by_8Q  q25_by_9Q  q25_by_10Q  Is_pass
# 0        96.666667  96.333333  96.000000   95.333333     True
# 1        96.666667  96.333333  96.000000   95.333333     True
# 2        96.666667  96.333333  96.000000   95.333333     True
# 3        96.666667  96.333333  96.000000   95.333333     True
# 4        96.666667  96.333333  96.000000   95.333333     True
# ...            ...        ...        ...         ...      ...
# 1641405  81.666667  80.333333  78.583333   77.000000    False
# 1641406  81.666667  80.333333  78.583333   77.000000    False
# 1641407  81.666667  80.333333  78.583333   77.000000    False
# 1641408  81.666667  80.333333  78.583333   77.000000    False
# 1641409  81.666667  80.333333  78.583333   77.000000    False
#
# [1641410 rows x 36 columns]

# %%
df['All_app']/=df['Quota']
df['Orig_all']/=df['Quota']
df['BVI']/=df['Quota']
df['Orig_above']/=df['Quota']

# %%
import seaborn as sns

sns.histplot(df[~df['Is_pass']]["Avg_score"])
# Out:
# <Axes: xlabel='Avg_score', ylabel='Count'>

# %%
df['Combined'] = df.apply(lambda row: f"{row['Year']} - {row['University']} - {row['Faculty']} - {row['Program']}", axis=1)
unique_values = df['Combined'].unique()
df
# Out:
#          Year        University                         Faculty  \
# 0        2017               ВШЭ  Департамент иностранных языков
# 1        2017               ВШЭ  Департамент иностранных языков
# 2        2017               ВШЭ  Департамент иностранных языков
# 3        2017               ВШЭ  Департамент иностранных языков
# 4        2017               ВШЭ  Департамент иностранных языков
# ...       ...               ...                             ...
# 1641405  2022  МГТУ им. Баумана                      AllFaculty
# 1641406  2022  МГТУ им. Баумана                      AllFaculty
# 1641407  2022  МГТУ им. Баумана                      AllFaculty
# 1641408  2022  МГТУ им. Баумана                      AllFaculty
# 1641409  2022  МГТУ им. Баумана                      AllFaculty
#
#                                                    Program  \
# 0        Лингвистика (45.03.02) (Иностранные языки и ме...
# 1        Лингвистика (45.03.02) (Иностранные языки и ме...
# 2        Лингвистика (45.03.02) (Иностранные языки и ме...
# 3        Лингвистика (45.03.02) (Иностранные языки и ме...
# 4        Лингвистика (45.03.02) (Иностранные языки и ме...
# ...                                                    ...
# 1641405            Ядерные реакторы и материалы (14.05.01)
# 1641406            Ядерные реакторы и материалы (14.05.01)
# 1641407            Ядерные реакторы и материалы (14.05.01)
# 1641408            Ядерные реакторы и материалы (14.05.01)
# 1641409            Ядерные реакторы и материалы (14.05.01)
#
#                                 Name  Score   Avg_score  Num_subjects  Quota  \
# 0             Бунтман Вера Сергеевна    309  103.000000             3     30
# 1           Мунтян Марина Евгеньевна    308  102.666667             3     30
# 2        Соколова Виктория Сергеевна    307  102.333333             3     30
# 3             Ужакина Анна Андреевна    307  102.333333             3     30
# 4           Крюкова Алеся Алексеевна    306  102.000000             3     30
# ...                              ...    ...         ...           ...    ...
# 1641405                  16103802721    174   58.000000             3     48
# 1641406                  16530926467    170   56.666667             3     48
# 1641407                  18467618619    162   54.000000             3     48
# 1641408                  18625786822    160   53.333333             3     48
# 1641409                  18566551716    155   51.666667             3     48
#
#            All_app  ...  q25_by_3Q  q25_by_4Q  q25_by_5Q  q25_by_6Q  \
# 0        47.100000  ...  98.666667  98.000000  97.333333       97.0
# 1        47.100000  ...  98.666667  98.000000  97.333333       97.0
# 2        47.100000  ...  98.666667  98.000000  97.333333       97.0
# 3        47.100000  ...  98.666667  98.000000  97.333333       97.0
# 4        47.100000  ...  98.666667  98.000000  97.333333       97.0
# ...            ...  ...        ...        ...        ...        ...
# 1641405   9.979167  ...  88.666667  86.666667  84.916667       83.0
# 1641406   9.979167  ...  88.666667  86.666667  84.916667       83.0
# 1641407   9.979167  ...  88.666667  86.666667  84.916667       83.0
# 1641408   9.979167  ...  88.666667  86.666667  84.916667       83.0
# 1641409   9.979167  ...  88.666667  86.666667  84.916667       83.0
#
#          q25_by_7Q  q25_by_8Q  q25_by_9Q  q25_by_10Q  Is_pass  \
# 0        96.666667  96.333333  96.000000   95.333333     True
# 1        96.666667  96.333333  96.000000   95.333333     True
# 2        96.666667  96.333333  96.000000   95.333333     True
# 3        96.666667  96.333333  96.000000   95.333333     True
# 4        96.666667  96.333333  96.000000   95.333333     True
# ...            ...        ...        ...         ...      ...
# 1641405  81.666667  80.333333  78.583333   77.000000    False
# 1641406  81.666667  80.333333  78.583333   77.000000    False
# 1641407  81.666667  80.333333  78.583333   77.000000    False
# 1641408  81.666667  80.333333  78.583333   77.000000    False
# 1641409  81.666667  80.333333  78.583333   77.000000    False
#
#                                                   Combined
# 0        2017 - ВШЭ - Департамент иностранных языков - ...
# 1        2017 - ВШЭ - Департамент иностранных языков - ...
# 2        2017 - ВШЭ - Департамент иностранных языков - ...
# 3        2017 - ВШЭ - Департамент иностранных языков - ...
# 4        2017 - ВШЭ - Департамент иностранных языков - ...
# ...                                                    ...
# 1641405  2022 - МГТУ им. Баумана - AllFaculty - Ядерные...
# 1641406  2022 - МГТУ им. Баумана - AllFaculty - Ядерные...
# 1641407  2022 - МГТУ им. Баумана - AllFaculty - Ядерные...
# 1641408  2022 - МГТУ им. Баумана - AllFaculty - Ядерные...
# 1641409  2022 - МГТУ им. Баумана - AllFaculty - Ядерные...
#
# [1641410 rows x 37 columns]

# %%
from sklearn.model_selection import train_test_split

train_indices, test_indices = train_test_split(unique_values, test_size=0.2, random_state = 23)

train_df = df[df['Combined'].isin(train_indices)].iloc[:,6:].drop(['Combined'], axis=1)
test_df = df[df['Combined'].isin(test_indices)].iloc[:,6:].drop(['Combined'], axis=1)

print(train_df.shape, test_df.shape)
print(test_indices[:5])
# Out:
# (1322566, 30) (318844, 30)
# ['2018 - МГУ - Факультет журналистики - Журналистика (42.03.02)'
#  '2017 - МАИ - б ф - Электроэнергетика и электротехника (13.03.02)'
#  '2019 - РАНХиГС - Северо-Западный институт управления - филиал - - - Журналистика (42.03.02) (Телерадиожурналистика)'
#  '2017 - ИТМО - Компьютерные технологии и управление - Управление в технических системах (27.03.04)'
#  '2019 - МИФИ - - - Атомные станции  проектирование, эксплуатация и инжиниринг (14.05.02)']

# %%
train_df.columns
# Out:
# Index(['Avg_score', 'Num_subjects', 'Quota', 'All_app', 'Orig_all', 'BVI',
#        'Orig_above', 'q90', 'q80', 'q75', 'q70', 'q65', 'q60', 'q55', 'q50',
#        'q40', 'q30', 'q20', 'q10', 'q25_by_1Q', 'q25_by_2Q', 'q25_by_3Q',
#        'q25_by_4Q', 'q25_by_5Q', 'q25_by_6Q', 'q25_by_7Q', 'q25_by_8Q',
#        'q25_by_9Q', 'q25_by_10Q', 'Is_pass'],
#       dtype='object')

# %%
cols = ['q75', 'q65', 'q55']
# cols = []
test_df = test_df.drop(cols, axis=1)
train_df = train_df.drop(cols, axis=1)
train_df
# Out:
#           Avg_score  Num_subjects  Quota    All_app   Orig_all  BVI  \
# 0        103.000000             3     30  47.100000  10.533333  0.6
# 1        102.666667             3     30  47.100000  10.533333  0.6
# 2        102.333333             3     30  47.100000  10.533333  0.6
# 3        102.333333             3     30  47.100000  10.533333  0.6
# 4        102.000000             3     30  47.100000  10.533333  0.6
# ...             ...           ...    ...        ...        ...  ...
# 1641405   58.000000             3     48   9.979167   1.020833  0.0
# 1641406   56.666667             3     48   9.979167   1.020833  0.0
# 1641407   54.000000             3     48   9.979167   1.020833  0.0
# 1641408   53.333333             3     48   9.979167   1.020833  0.0
# 1641409   51.666667             3     48   9.979167   1.020833  0.0
#
#          Orig_above        q90        q80        q70  ...  q25_by_2Q  \
# 0          0.733333  97.000000  94.066667  92.000000  ...  99.333333
# 1          0.766667  97.000000  94.066667  92.000000  ...  99.333333
# 2          0.766667  97.000000  94.066667  92.000000  ...  99.333333
# 3          0.800000  97.000000  94.066667  92.000000  ...  99.333333
# 4          0.800000  97.000000  94.066667  92.000000  ...  99.333333
# ...             ...        ...        ...        ...  ...        ...
# 1641405    1.020833  92.333333  89.666667  86.666667  ...  91.000000
# 1641406    1.020833  92.333333  89.666667  86.666667  ...  91.000000
# 1641407    1.020833  92.333333  89.666667  86.666667  ...  91.000000
# 1641408    1.020833  92.333333  89.666667  86.666667  ...  91.000000
# 1641409    1.020833  92.333333  89.666667  86.666667  ...  91.000000
#
#          q25_by_3Q  q25_by_4Q  q25_by_5Q  q25_by_6Q  q25_by_7Q  q25_by_8Q  \
# 0        98.666667  98.000000  97.333333       97.0  96.666667  96.333333
# 1        98.666667  98.000000  97.333333       97.0  96.666667  96.333333
# 2        98.666667  98.000000  97.333333       97.0  96.666667  96.333333
# 3        98.666667  98.000000  97.333333       97.0  96.666667  96.333333
# 4        98.666667  98.000000  97.333333       97.0  96.666667  96.333333
# ...            ...        ...        ...        ...        ...        ...
# 1641405  88.666667  86.666667  84.916667       83.0  81.666667  80.333333
# 1641406  88.666667  86.666667  84.916667       83.0  81.666667  80.333333
# 1641407  88.666667  86.666667  84.916667       83.0  81.666667  80.333333
# 1641408  88.666667  86.666667  84.916667       83.0  81.666667  80.333333
# 1641409  88.666667  86.666667  84.916667       83.0  81.666667  80.333333
#
#          q25_by_9Q  q25_by_10Q  Is_pass
# 0        96.000000   95.333333     True
# 1        96.000000   95.333333     True
# 2        96.000000   95.333333     True
# 3        96.000000   95.333333     True
# 4        96.000000   95.333333     True
# ...            ...         ...      ...
# 1641405  78.583333   77.000000    False
# 1641406  78.583333   77.000000    False
# 1641407  78.583333   77.000000    False
# 1641408  78.583333   77.000000    False
# 1641409  78.583333   77.000000    False
#
# [1322566 rows x 27 columns]

# %%
from pycaret.classification import *
stp = setup(train_df, target = 'Is_pass', test_data=test_df)
# Out:
# <style type="text/css">
# #T_91948_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_91948">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91948_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_91948_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91948_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_91948_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_91948_row0_col1" class="data row0 col1" >7808</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_91948_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_91948_row1_col1" class="data row1 col1" >Is_pass</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_91948_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_91948_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_91948_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_91948_row3_col1" class="data row3 col1" >(1641410, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_91948_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_91948_row4_col1" class="data row4 col1" >(1641410, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_91948_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_91948_row5_col1" class="data row5 col1" >(1322566, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_91948_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_91948_row6_col1" class="data row6 col1" >(318844, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_91948_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_91948_row7_col1" class="data row7 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_91948_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_91948_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_91948_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_91948_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_91948_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_91948_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_91948_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_91948_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_91948_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_91948_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_91948_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_91948_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_91948_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_91948_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_91948_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_91948_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_91948_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_91948_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_91948_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_91948_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_91948_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_91948_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_91948_row18_col1" class="data row18 col1" >e9cd</td>
#     </tr>
#   </tbody>
# </table>

# %%
from catboost import CatBoostClassifier

X = stp.X_test
y = stp.y_test

X_train = stp.X_train
y_train = stp.y_train

# CatBoost Model
cat_model = CatBoostClassifier(eval_metric='Logloss', early_stopping_rounds=100, verbose = False)
cat_model.fit(X_train, y_train, eval_set=(X, y))

# %%
from sklearn.metrics import f1_score, roc_auc_score, recall_score, precision_score, precision_recall_curve, accuracy_score

def metrics(model, X_test, y_test):
    X_pred_prob = model.predict_proba(X_test)[:, 1]
    X_pred = model.predict(X_test)
    
    f1 = f1_score(y_test, X_pred)
    auc = roc_auc_score(y_test, X_pred_prob)
    prec = precision_score(y_test, X_pred)
    rec = recall_score(y_test, X_pred)
    acc = accuracy_score(y_test, X_pred)
    
    print(f"Accuracy: {acc}")
    print(f"AUC: {auc}")
    print(f"Precision: {prec}")
    print(f"Recall: {rec}")
    print(f"F1: {f1}")

metrics(cat_model, X, y)
# Out:
# Accuracy: 0.8926998783103963
# AUC: 0.9584613645623251
# Precision: 0.86147058055645
# Recall: 0.8440183146747611
# F1: 0.852655153107369

# %%
def best_f1(model, X_test, y_test):
    X_pred_prob = model.predict_proba(X_test)[:, 1]
    # Вычисляем precision, recall и thresholds
    precision, recall, thresholds = precision_recall_curve(y_test, X_pred_prob)
    
    # Вычисляем F1-score для каждого порога
    f1_scores = [2 * (p * r) / (p + r) for p, r in zip(precision, recall)]
    
    # Находим порог, который максимизирует F1-score
    best_id = np.argmax(f1_scores)
    best_threshold = thresholds[best_id]
    best_f1 = np.max(f1_scores)
    best_prec = precision[best_id]
    best_rec = recall[best_id]
    
    print(f"Лучший порог: {best_threshold}")
    print(f"Лучшая точность (precision): {best_prec}")
    print(f"Лучшая полнота (recall): {best_rec}")
    print(f"Лучший F1-score: {best_f1}")

best_f1(cat_model, X, y)
# Out:
# Лучший порог: 0.4538403688479869
# Лучшая точность (precision): 0.8472186233125758
# Лучшая полнота (recall): 0.8642087941133839
# Лучший F1-score: 0.8556293738761935

# %%
evaluate_model(cat_model)

# %%
interpret_model(cat_model)

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(eval_metric='logloss', use_label_encoder=False)
xgb_model.fit(X_train, y_train, eval_set=[(X, y)], verbose= False)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, objective='binary:logistic', ...)

# %%
metrics(xgb_model, X, y)
# Out:
# Accuracy: 0.8910376234145851
# AUC: 0.9579811392972608
# Precision: 0.8652095040042476
# Recall: 0.8336502306387115
# F1: 0.8491367331341625

# %%
best_f1(xgb_model, X, y)
# Out:
# Лучший порог: 0.33440229296684265
# Лучшая точность (precision): 0.8286046849992725
# Лучшая полнота (recall): 0.8740397159008552
# Лучший F1-score: 0.8507159840163986

# %%
evaluate_model(xgb_model)

# %%
interpret_model(xgb_model)

# %%
from lightgbm import LGBMClassifier

lgb_model = LGBMClassifier(metric='logloss')
lgb_model.fit(X_train, y_train, eval_set=[(X, y)])
# Out:
# [LightGBM] [Info] Number of positive: 505529, number of negative: 817037
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.085310 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5764
# [LightGBM] [Info] Number of data points in the train set: 1322566, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.382233 -> initscore=-0.480079
# [LightGBM] [Info] Start training from score -0.480079
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                metric='logloss', min_child_samples=20, min_child_weight=0.001,
#                min_split_gain=0.0, n_estimators=100, n_jobs=None, num_leaves=31,
#                objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
metrics(lgb_model, X, y)
# Out:
# Accuracy: 0.8919534317722774
# AUC: 0.9604327875654559
# Precision: 0.8611578607741744
# Recall: 0.8420231406086134
# F1: 0.8514830143128126

# %%
best_f1(lgb_model, X, y)
# Out:
# Лучший порог: 0.34897153862367786
# Лучшая точность (precision): 0.8201295855765619
# Лучшая полнота (recall): 0.8936162956268172
# Лучший F1-score: 0.8552973579516475

# %%
evaluate_model(lgb_model)

# %%
interpret_model(lgb_model)

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)

metrics(lr_model, X, y)
# Out:
# Accuracy: 0.8602796351820953
# AUC: 0.9337574742153021
# Precision: 0.82235675790668
# Recall: 0.7910353589181723
# F1: 0.8063920312561115

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

metrics(rf_model, X, y)
# Out:
# Accuracy: 0.8876409780331448
# AUC: 0.9565110663386385
# Precision: 0.8354444975209606
# Recall: 0.8648994312901273
# F1: 0.8499168415716734

# %%
from sklearn.ensemble import VotingClassifier

voting_clf = VotingClassifier(
    estimators=[
        ('catboost', cat_model),
        ('xgboost', xgb_model),
        ('lightgbm', lgb_model)
    ],
    voting='soft'
)


voting_clf.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 505529, number of negative: 817037
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.083339 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5764
# [LightGBM] [Info] Number of data points in the train set: 1322566, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.382233 -> initscore=-0.480079
# [LightGBM] [Info] Start training from score -0.480079
# VotingClassifier(estimators=[('catboost',
#                               <catboost.core.CatBoostClassifier object at 0x0000025DF7263C10>),
#                              ('xgboost',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric='logloss',
#                                             feature_types=None, gamma=...
#                                              learning_rate=0.1, max_depth=-1,
#                                              metric='logloss',
#                                              min_child_samples=20,
#                                              min_child_weight=0.001,
#                                              min_split_gain=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              num_leaves=31, objective=None,
#                                              random_state=None, reg_alpha=0.0,
#                                              reg_lambda=0.0, subsample=1.0,
#                                              subsample_for_bin=200000,
#                                              subsample_freq=0))],
#                  flatten_transform=True, n_jobs=None, verbose=False,
#                  voting='soft', weights=None)

# %%
metrics(voting_clf, X, y)
# Out:
# Accuracy: 0.8945722673156778
# AUC: 0.9613723143764025
# Precision: 0.8672355068647073
# Recall: 0.8423386168498418
# F1: 0.8546057725163171

# %%
best_f1(voting_clf, X, y)
# Out:
# Лучший порог: 0.39503919493225403
# Лучшая точность (precision): 0.8441908096858379
# Лучшая полнота (recall): 0.8715500115106196
# Лучший F1-score: 0.8576522756925246

# %%
evaluate_model(voting_clf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
check_fairness(voting_clf, sensitive_features = ['Num_subjects'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_76078">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76078_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_76078_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_76078_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_76078_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_76078_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_76078_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_76078_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_76078_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76078_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76078_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_76078_row0_col1" class="data row0 col1" >0.8946</td>
#       <td id="T_76078_row0_col2" class="data row0 col2" >0.9614</td>
#       <td id="T_76078_row0_col3" class="data row0 col3" >0.8423</td>
#       <td id="T_76078_row0_col4" class="data row0 col4" >0.8672</td>
#       <td id="T_76078_row0_col5" class="data row0 col5" >0.8546</td>
#       <td id="T_76078_row0_col6" class="data row0 col6" >0.7719</td>
#       <td id="T_76078_row0_col7" class="data row0 col7" >0.7721</td>
#     </tr>
#   </tbody>
# </table>
#                Samples  Accuracy       AUC    Recall  Precision        F1  \
# Num_subjects
# 3             282774.0  0.890973  0.882442  0.846609   0.864407  0.855416
# 4              35623.0  0.923027  0.881116  0.793318   0.900280  0.843422
# 5                447.0  0.903803  0.913655  0.827309   1.000000  0.905495
#
#                  Kappa       MCC  Selection Rate
# Num_subjects
# 3             0.767924  0.768031        0.373114
# 4             0.792662  0.795449        0.230273
# 5             0.809310  0.824438        0.460850

# %%
save_model(voting_clf, 'prediction_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Avg_score', 'Num_subjects',
#                                               'Quota', 'All_app', 'Orig_all',
#                                               'BVI', 'Orig_above', 'q90', 'q80',
#                                               'q70', 'q60', 'q50', 'q40', 'q30',
#                                               'q20', 'q10', 'q25_by_1Q',
#                                               'q25_by_2Q', 'q25_by_3Q',
#                                               'q25_by_4Q', 'q25_by_5Q',
#                                               'q25_by_6Q', 'q25_by_7Q',
#                                               'q25_by_8Q', 'q25_by_9Q',
#                                               'q25_b...
#                                                                max_depth=-1,
#                                                                metric='logloss',
#                                                                min_child_samples=20,
#                                                                min_child_weight=0.001,
#                                                                min_split_gain=0.0,
#                                                                n_estimators=100,
#                                                                n_jobs=None,
#                                                                num_leaves=31,
#                                                                objective=None,
#                                                                random_state=None,
#                                                                reg_alpha=0.0,
#                                                                reg_lambda=0.0,
#                                                                subsample=1.0,
#                                                                subsample_for_bin=200000,
#                                                                subsample_freq=0))],
#                                    flatten_transform=True, n_jobs=None,
#                                    verbose=False, voting='soft',
#                                    weights=None))],
#           verbose=False),
#  'prediction_model.pkl')

# %%
voting_clf = load_model('prediction_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
import matplotlib.pyplot as plt
def plot(name, a, s, is_test, i):
    n= 110
    m= 110
    
    pd_df = pd.DataFrame({col: [val]*n*m for col, val in a.items()})
    
    # Create the meshgrid
    c, d = np.meshgrid(np.linspace(0, 2.5, n), np.linspace(50,110, m))
    
    # Convert the meshgrid to a DataFrame
    pd_df['Orig_above'] = c.flatten()
    pd_df['Avg_score'] = d.flatten()
    
    y_pred_proba = voting_clf.predict_proba(pd_df)[:,1]
    
    
    quota = a['Quota']
    num = a['Num_subjects']
    # Plot the graph
    plt.figure(figsize=(5, 4))
    plt.contourf(c*quota, d*num, y_pred_proba.reshape(m, n), cmap='RdBu_r')
    plt.scatter(x= quota*s['Orig_above'],y=num*s['Avg_score'], c= s['Is_pass'], cmap='seismic')
    plt.colorbar(label='Prediction')
    plt.xlabel('Orig_above')
    plt.ylabel('Avg_score')
    plt.axvline(x=a['Quota'], color='k', linestyle='--', label='Quota')
    plt.title(name)
    
    path = "Assets/"
    if is_test: path+="Test/"
    else: path+="Train/"
    path+=f"{name[:120]}.png"
    plt.savefig(path, dpi=300, bbox_inches='tight')
    if i%500==0: plt.show()
    plt.close()

# %%
for i in range(len(unique_values)):
    name = unique_values[i]
    is_test = False
    if name in test_indices: is_test = True
    s = df[df['Combined'].str.contains(name, regex=False)]
    s = s[s['Avg_score'] > 50]
    s = s[s['Orig_above']< 2.5]
    def pipeline(s):
        return s.iloc[0,6:].drop(['Combined', 'Is_pass']+cols)
    a = pipeline(s)
    plot(name, a, s, is_test, i)
    print(name)
